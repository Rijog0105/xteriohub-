# %% [markdown]
# # XTERIOHUB Custom Façade AI — Google Colab Training Notebook
# This notebook fine-tunes a specialized Image-to-Image Façade Visualization model on a cloud GPU.

# %%
# 1. Check GPU
# !nvidia-smi

# %%
# 2. Install Dependencies
# !pip install -q diffusers transformers accelerate peft safetensors opencv-python pillow pyyaml tqdm

# %%
# 3. Run Synthetic Dataset Generator
# %cd /content/plan web/ai-model/preprocessing
# !python generate_synthetic_pairs.py
# !python prepare_dataset.py

# %%
# 4. Start LoRA Training with Masked Loss
# %cd /content/plan web/ai-model/training
# !python train_lora.py

# %%
# 5. Save Checkpoints to Google Drive
from google.colab import drive
drive.mount('/content/drive')
# !cp -r /content/plan\ web/ai-model/checkpoints /content/drive/MyDrive/xteriohub_facade_checkpoints
